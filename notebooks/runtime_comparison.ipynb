# %%
import torch
from time import perf_counter
from torch.utils import benchmark
from itertools import product

torch.cuda.seed_all()

# %%
def landing_step_inplace(
    param: torch.Tensor, grad: torch.Tensor, I: torch.Tensor
) -> torch.Tensor:

    G = grad @ param.t()          # G shape: (n, n)
    G = G - G.t()

    distance = param.t() @ param  
    distance.sub_(I)              # in-place distance = distance - I

    return param - (G @ param + param @ distance)


"""
Polar retraction from pymanopt: https://pymanopt.org/docs/stable/_modules/pymanopt/manifolds/stiefel.html#Stiefel
    def _retraction_polar(self, point, tangent_vector):
        Y = point + tangent_vector
        u, _, vt = np.linalg.svd(Y, full_matrices=False)
        return u @ vt
"""

# def conditioner_step(param: torch.Tensor, grad: torch.Tensor, I: torch.Tensor):
#     cond = torch.matmul(grad.T, grad)
#     cond.add_(I)
#     L, Q = torch.linalg.eigh(cond)
#     L.rsqrt_()
#     polar_factor = Q @ torch.diag(L) @ Q.T
#     return torch.matmul(param, polar_factor)

def conditioner_step(param: torch.Tensor, grad: torch.Tensor, I: torch.Tensor):
    Y = param + grad
    u, _, vt = torch.linalg.svd(Y, full_matrices=False)
    return torch.matmul(u, vt)

# %%
device = 'cuda:7'

# %%
param = torch.randn(4096, 32, device=device)
n, p = param.shape
I = torch.eye(p, device=param.device)
comp = torch.compile(landing_step_inplace)
for _ in range(10):
    _ = comp(param, param, I)

comp_conditioner = torch.compile(conditioner_step)
for _ in range(10):
    _ = comp_conditioner(param,param, I)

# %%
results = []

n_grid = [768, 4096, 11008]
r_grid = [4, 32, 64, 256]
for n, r in product(n_grid, r_grid):
    # label and sub_label are the rows
    # description is the column
    label = 'retraction/landing'
    sub_label = f'[{n}, {r}]'
    param = torch.randn((n, r), device=device)
    I = torch.eye(r, device=param.device)
    results.append(benchmark.Timer(
        stmt='comp_conditioner(param, param, I)',
        setup='from __main__ import comp_conditioner',
        label=label,
        sub_label=sub_label,
        description='retraction',
        globals={'param': param, "I": I}).adaptive_autorange(threshold=0.15, min_run_time=1.0, max_run_time=5.0))
    results.append(benchmark.Timer(
        stmt='comp(param, param, I)',
        setup='from __main__ import comp',
        label=label,
        sub_label=sub_label,
        description='landing',
        globals={'param': param, "I": I}).adaptive_autorange(threshold=0.15, min_run_time=1.0, max_run_time=5.0))

compare = benchmark.Compare(results)
#compare.trim_significant_figures()
compare.print()
# Out:
# [------------ retraction/landing -----------]
#                     |  retraction  |  landing
# 1 threads: ----------------------------------
#       [768, 4]      |     507.2    |    167.5
#       [768, 32]     |    1160.3    |    100.4
#       [768, 64]     |    2178.1    |    102.7
#       [768, 256]    |    8317.5    |    109.9
#       [4096, 4]     |     541.6    |    180.9
#       [4096, 32]    |    1050.3    |    186.4
#       [4096, 64]    |    1916.2    |    238.4
#       [4096, 256]   |    9889.4    |    539.7
#       [11008, 4]    |     606.7    |   1785.8
#       [11008, 32]   |    1312.7    |   1233.6
#       [11008, 64]   |    2237.7    |   1632.7
#       [11008, 256]  |   11653.9    |   3606.4
#
# Times are in microseconds (us).

# %%
for i, measurement in enumerate(results):
    print(f"\n---- Measurement {i} details ----")
    print(measurement)
    print("Number of runs per repeat:", measurement.number_per_run)
    print("Times (seconds):", measurement.times)
    print("Median (seconds):", measurement.median)
    print("IQR (seconds):", measurement.iqr)
# Out:
# ---- Measurement 0 details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0
details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e3760>
# retraction/landing: [768, 64]
# landing
# setup: from __main__ import comp
#   Median: 102.71 us
#   IQR:    0.99 us (101.76 to 102.75)
#   10 measurements, 1000 runs per measurement, 1 thread
# Number of runs per repeat: 1000
# Times (seconds): [0.00010274027939885855, 0.00010133138950914145, 0.00010154571756720543, 0.00010145686753094197, 0.00010280316881835461, 0.00010275187902152539, 0.00010267271846532822, 0.00010274957865476609, 0.00010239828191697597, 0.00010300726816058159]
# Median (seconds): 0.00010270649893209338
# IQR (seconds): 9.924452751874832e-07
#
# ---- Measurement 6 details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e2110>
# retraction/landing: [768, 256]
# retraction
# setup: from __main__ import comp_conditioner
#   Median: 8.32 ms
#   IQR:    0.01 ms (8.31 to 8.32)
#   13 measurements, 10 runs per measurement, 1 thread
# Number of runs per repeat: 10
# Times (seconds): [0.008337979204952717, 0.008310991246253252, 0.008315153326839209, 0.008312663249671459, 0.008306191395968198, 0.008324146177619696, 0.008302101399749517, 0.00840505063533783, 0.008321642316877842, 0.008317485358566046, 0.008324283175170422, 0.008307661302387715, 0.008326515182852745]
# Median (seconds): 0.008317485358566046
# IQR (seconds): 1.3291928917169224e-05
#
# ---- Measurement 7 details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e1840>
# retraction/landing: [768, 256]
# landing
# setup: from __main__ import comp
#   Median: 109.94 us
#   IQR:    0.37 us (109.70 to 110.07)
#   10 measurements, 1000 runs per measurement, 1 thread
# Number of runs per repeat: 1000
# Times (seconds): [0.00011022022925317288, 0.00010883300658315421, 0.00010970980208367109, 0.00010969638172537088, 0.00011004162952303887, 0.0001093700136989355, 0.00010997247043997049, 0.00011093861423432826, 0.00010991030093282461, 0.00011007904913276435]
# Median (seconds): 0.00010994138568639754
# IQR (seconds): 3.699574153870382e-07
#
# ---- Measurement 8 details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e2830>
# retraction/landing: [4096, 4]
# retraction
# setup: from __main__ import comp_conditioner
#   Median: 541.62 us
#   IQR:    0.89 us (541.31 to 542.20)
#   19 measurements, 100 runs per measurement, 1 thread
# Number of runs per repeat: 100
# Times (seconds): [0.0005447384808212519, 0.0005419833026826382, 0.0005410476122051477, 0.0005411170143634081, 0.0005422638915479184, 0.0005474776681512595, 0.0005414539948105813, 0.0005418957117944956, 0.0005426582042127848, 0.0005421357043087483, 0.0005412773042917251, 0.0005415103957056999, 0.0005424453131854534, 0.0005413369089365005, 0.0005409382097423076, 0.0005420798063278198, 0.0005416175071150064, 0.0005407142080366611, 0.0005415218137204647]
# Median (seconds): 0.0005416175071150064
# IQR (seconds): 8.926913142205542e-07
#
# ---- Measurement 9 details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e1360>
# retraction/landing: [4096, 4]
# landing
# setup: from __main__ import comp
#   Median: 180.91 us
#   IQR:    0.45 us (180.69 to 181.14)
#   6 measurements, 1000 runs per measurement, 1 thread
# Number of runs per repeat: 1000
# Times (seconds): [0.00017261773254722356, 0.00018110914528369904, 0.00018116980418562888, 0.000181156724691391, 0.0001806875979527831, 0.000180712197907269]
# Median (seconds): 0.00018091067159548403
# IQR (seconds): 4.5108189806341735e-07
#
# ---- Measurement 10 details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e2a10>
# retraction/landing: [4096, 32]
# retraction
# setup: from __main__ import comp_conditioner
#   Median: 1.05 ms
#   IQR:    0.00 ms (1.05 to 1.05)
#   10 measurements, 100 runs per measurement, 1 thread
# Number of runs per repeat: 100
# Times (seconds): [0.0010529746208339929, 0.0010497773345559836, 0.001050611948594451, 0.0010500478465110064, 0.0010506160371005534, 0.001049709441140294, 0.00104953084141016, 0.0010504523385316134, 0.0010501428414136172, 0.00105175512842834]
# Median (seconds): 0.0010502975899726154
# IQR (seconds): 7.70052429288539e-07
#
# ---- Measurement 11 details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e3010>
# retraction/landing: [4096, 32]
# landing
# setup: from __main__ import comp
#   Median: 186.43 us
#   IQR:    2.44 us (186.15 to 188.59)
#   6 measurements, 1000 runs per measurement, 1 thread
# Number of runs per repeat: 1000
# Times (seconds): [0.00017801189608871937, 0.00018614265974611045, 0.00018615790084004403, 0.0001892215795814991, 0.00019350317027419804, 0.0001866948362439871]
# Median (seconds): 0.00018642636854201554
# IQR (seconds): 2.4434237275272445e-06
#
# ---- Measurement 12 details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e2bf0>
# retraction/landing: [4096, 64]
# retraction
# setup: from __main__ import comp_conditioner
#   Median: 1.92 ms
#   IQR:    0.00 ms (1.92 to 1.92)
#   6 measurements, 100 runs per measurement, 1 thread
# Number of runs per repeat: 100
# Times (seconds): [0.0019199924077838658, 0.0019158456381410361, 0.001916031138971448, 0.0019149545393884182, 0.0019168589357286693, 0.0019162934273481368]
# Median (seconds): 0.0019161622831597924
# IQR (seconds): 8.255452848971844e-07
#
# ---- Measurement 13 details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e3d30>
# retraction/landing: [4096, 64]
# landing
# setup: from __main__ import comp
#   Median: 238.37 us
#   IQR:    0.27 us (238.12 to 238.38)
#   5 measurements, 1000 runs per measurement, 1 thread
# Number of runs per repeat: 1000
# Times (seconds): [0.00022639487590640783, 0.000238365663215518, 0.00023840929474681615, 0.0002383814249187708, 0.00023811617586761712]
# Median (seconds): 0.000238365663215518
# IQR (seconds): 2.6524905115366763e-07
#
# ---- Measurement 14 details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e2d40>
# retraction/landing: [4096, 256]
# retraction
# setup: from __main__ import comp_conditioner
#   Median: 9.89 ms
#   IQR:    0.01 ms (9.88 to 9.90)
#   11 measurements, 10 runs per measurement, 1 thread
# Number of runs per repeat: 10
# Times (seconds): [0.009909359551966191, 0.009895350597798825, 0.00987331261858344, 0.009889412671327591, 0.009892059676349162, 0.009895008429884911, 0.009884970635175705, 0.009886513650417327, 0.009876570757478475, 0.009904163517057895, 0.009883202612400055]
# Median (seconds): 0.009889412671327591
# IQR (seconds): 1.1092890053989585e-05
#
# ---- Measurement 15 details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e1f90>
# retraction/landing: [4096, 256]
# landing
# setup: from __main__ import comp
#   Median: 539.74 us
#   IQR:    2.45 us (537.98 to 540.42)
#   4 measurements, 1000 runs per measurement, 1 thread
# Number of runs per repeat: 1000
# Times (seconds): [0.000533064715564251, 0.0005398606695234775, 0.0005396173009648919, 0.0005421151630580426]
# Median (seconds): 0.0005397389852441847
# IQR (seconds): 2.4451382923870984e-06
#
# ---- Measurement 16 details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e1600>
# retraction/landing: [11008, 4]
# retraction
# setup: from __main__ import comp_conditioner
#   Median: 606.69 us
#   IQR:    8.20 us (602.40 to 610.61)
#   1647 measurements, 1 runs per measurement, 1 thread
# Number of runs per repeat: 1
# Times (seconds): [0.000790783204138279, 0.0006027957424521446, 0.000611606054008007, 0.0006114449352025986, 0.0006312653422355652, 0.0006100153550505638, 0.0006056362763047218, 0.0006147259846329689, 0.0006075659766793251, 0.0006145955994725227, 0.0006049647927284241, 0.0006090262904763222, 0.0006110267713665962, 0.0006053345277905464, 0.0006139557808637619, 0.000604536384344101, 0.0006245160475373268, 0.000604456290602684, 0.000684024766087532, 0.0006243251264095306, 0.0006075659766793251, 0.0006030555814504623, 0.0006012367084622383, 0.0006058160215616226, 0.0006071459501981735, 0.0005964161828160286, 0.0006187157705426216, 0.0006081657484173775, 0.000604456290602684, 0.0005965763702988625, 0.0005960362032055855, 0.0006043855100870132, 0.0006038565188646317, 0.0006060255691409111, 0.000601036474108696, 0.0006051063537597656, 0.0006182761862874031, 0.000616585835814476, 0.0006126649677753448, 0.0006034653633832932, 0.0006053252145648003, 
200745821, 0.011755239218473434, 0.011746690608561039, 0.011737469583749771, 0.01174112968146801, 0.011750349774956703, 0.011750038713216782, 0.011736409738659859, 0.011749539524316788, 0.011711450293660164, 0.011646400205790997, 0.011625220999121666, 0.011647971346974373, 0.011655029840767384, 0.01165057998150587, 0.011642709374427795, 0.011630400083959103, 0.011649630963802338, 0.011611510999500751, 0.011620351113379002, 0.011634980328381062, 0.011633150279521942, 0.011621810495853424, 0.011620541103184223, 0.011661401018500328, 0.011629770509898663, 0.011646421626210213, 0.011632140725851059, 0.011655580252408981, 0.011652749963104725, 0.01166347973048687, 0.011634579859673977, 0.011648539453744888, 0.011644570156931877, 0.011646430008113384, 0.011628380976617336, 0.011629180982708931, 0.011641210876405239, 0.011646680533885956, 0.011612391099333763, 0.011628730222582817, 0.011668030172586441, 0.011652300134301186, 0.011642850004136562, 0.011662350036203861, 0.011674860492348671, 0.011658650822937489, 0.011640540324151516, 0.011640651151537895, 0.011659140698611736, 0.011655920185148716, 0.01162440050393343, 0.011635709553956985, 0.011955617927014828, 0.011648380197584629, 0.011639179661870003, 0.011635701172053814, 0.01163587998598814, 0.011606071144342422, 0.011646151542663574, 0.011635711416602135, 0.011643070727586746, 0.011656130664050579, 0.011629951186478138, 0.01166516076773405, 0.011645530350506306]
# Median (seconds): 0.011653889901936054
# IQR (seconds): 0.00010620756074786186
#
# ---- Measurement 23 details ----
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e07f0>
# retraction/landing: [11008, 256]
# landing
# setup: from __main__ import comp
#   Median: 3.61 ms
#   2 measurements, 1000 runs per measurement, 1 thread
# Number of runs per repeat: 1000
# Times (seconds): [0.003602692234329879, 0.003610192013904452]
# Median (seconds): 0.003606442124117166
# IQR (seconds): 3.7498897872867594e-06

# %%
# Benchmark takaes care of warm up
param = torch.randn(4096, 32, device=device)
n, p = param.shape
I = torch.eye(p, device=param.device)

t0 = benchmark.Timer(
    stmt='comp_conditioner(param, param, I)',
    setup='from __main__ import comp_conditioner',
    globals={'param': param, "I": I})

t1 = benchmark.Timer(
    stmt='comp(param, param, I)',
    setup='from __main__ import comp',
    globals={'param': param, "I": I})

# Run only once since benchmark module does warm-up for us
print(t0.timeit(1000))
print(t1.timeit(1000))
# Out:
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bc3e0a00>
# comp_conditioner(param, param, I)
# setup: from __main__ import comp_conditioner
#   1.06 ms
#   1 measurement, 1000 runs , 1 thread
# <torch.utils.benchmark.utils.common.Measurement object at 0x70e0bd570bb0>
# comp(param, param, I)
# setup: from __main__ import comp
#   165.64 us
#   1 measurement, 1000 runs , 1 thread

# %%
num_iter = 1000

torch.cuda.synchronize(device=device)
start = perf_counter()
for _ in range(num_iter):
    out = comp(param, param, I)
torch.cuda.synchronize(device=device)
end = perf_counter()

print(f"Landing (comp()) execution time: {end - start} seconds")

## Retraction
torch.cuda.synchronize(device=device)
start = perf_counter()
for _ in range(num_iter):
    out = comp_conditioner(param, param, I)
torch.cuda.synchronize(device=device)
end = perf_counter()

print(f"Retraction (comp_conditioner()) execution time: {end - start} seconds")
# Out:
# Landing (comp()) execution time: 0.1880705077201128 seconds
# Retraction (comp_conditioner()) execution time: 1.0508270850405097 seconds
